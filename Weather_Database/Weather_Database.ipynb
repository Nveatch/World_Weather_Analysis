# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Citypy import
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Nearest city list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 1 | grand forks
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | sayyan
# Processing Record 9 of Set 1 | ulaanbaatar
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | along
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | porbandar
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | macenta
# Processing Record 27 of Set 1 | coquimbo
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | chapada dos guimaraes
# Processing Record 34 of Set 1 | thohoyandou
# Processing Record 35 of Set 1 | deputatskiy
# Processing Record 36 of Set 1 | millau
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | shache
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | jutai
# Processing Record 43 of Set 1 | fare
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | goundam
# Processing Record 46 of Set 1 | bitung
# Processing Record 47 of Set 1 | vestmannaeyjar
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | shakiso
# Processing Record 50 of Set 1 | fortuna
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | farah
# Processing Record 3 of Set 2 | lima
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 2 | tariba
# Processing Record 7 of Set 2 | huilong
# Processing Record 8 of Set 2 | henties bay
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | mount isa
# Processing Record 11 of Set 2 | songjianghe
# Processing Record 12 of Set 2 | havre-saint-pierre
# Processing Record 13 of Set 2 | ardatov
# Processing Record 14 of Set 2 | qaqortoq
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | ceyhan
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | alvorada
# Processing Record 20 of Set 2 | ambon
# Processing Record 21 of Set 2 | goderich
# Processing Record 22 of Set 2 | varhaug
# Processing Record 23 of Set 2 | kangaatsiaq
# Processing Record 24 of Set 2 | masallatah
# Processing Record 25 of Set 2 | kavaratti
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | ravar
# Processing Record 32 of Set 2 | ekhabi
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | yantal
# Processing Record 35 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 2 | gerash
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | hovd
# Processing Record 39 of Set 2 | virginia beach
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | lodja
# Processing Record 43 of Set 2 | xinglongshan
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 2 | asfi
# Processing Record 1 of Set 3 | brufut
# Processing Record 2 of Set 3 | grand gaube
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | murray bridge
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | kondinskoye
# Processing Record 11 of Set 3 | novikovo
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | sydney mines
# Processing Record 15 of Set 3 | orlik
# Processing Record 16 of Set 3 | otavi
# Processing Record 17 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 3 | naze
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | pemangkat
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | likhoy
# Processing Record 24 of Set 3 | meulaboh
# Processing Record 25 of Set 3 | lensk
# Processing Record 26 of Set 3 | skibbereen
# Processing Record 27 of Set 3 | ulaangom
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | atambua
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | cairns
# Processing Record 33 of Set 3 | alamosa
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | magdagachi
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | coaldale
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | scarborough
# Processing Record 42 of Set 3 | burgeo
# Processing Record 43 of Set 3 | fort frances
# Processing Record 44 of Set 3 | verkh-usugli
# Processing Record 45 of Set 3 | pedasi
# Processing Record 46 of Set 3 | matagami
# Processing Record 47 of Set 3 | bahar
# Processing Record 48 of Set 3 | kholodnyy
# Processing Record 49 of Set 3 | jiangyou
# Processing Record 50 of Set 3 | rockport
# Processing Record 1 of Set 4 | eyl
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | port augusta
# Processing Record 4 of Set 4 | la huacana
# Processing Record 5 of Set 4 | bamiantong
# Processing Record 6 of Set 4 | emerald
# Processing Record 7 of Set 4 | vilhena
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | rawson
# Processing Record 10 of Set 4 | geneva
# Processing Record 11 of Set 4 | keetmanshoop
# Processing Record 12 of Set 4 | pangkalanbuun
# Processing Record 13 of Set 4 | rio grande
# Processing Record 14 of Set 4 | wahiawa
# Processing Record 15 of Set 4 | mbekenyera
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | arraial do cabo
# Processing Record 18 of Set 4 | hobyo
# Processing Record 19 of Set 4 | urengoy
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | broome
# Processing Record 23 of Set 4 | pecos
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | haines junction
# Processing Record 26 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | lima duarte
# Processing Record 29 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 4 | iranshahr
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | vardo
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | channel-port aux basques
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | jaipur hat
# City not found. Skipping...
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | darhan
# Processing Record 42 of Set 4 | gazojak
# Processing Record 43 of Set 4 | rabo de peixe
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | makakilo city
# Processing Record 46 of Set 4 | cape town
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | deniliquin
# Processing Record 49 of Set 4 | puerto berrio
# Processing Record 50 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 5 | husavik
# Processing Record 2 of Set 5 | sacalum
# Processing Record 3 of Set 5 | flinders
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | kathu
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | chitral
# Processing Record 8 of Set 5 | veere
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | klichka
# Processing Record 11 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | adrar
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | sakakah
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | swift current
# Processing Record 18 of Set 5 | surgut
# Processing Record 19 of Set 5 | vilyuysk
# Processing Record 20 of Set 5 | gainesville
# Processing Record 21 of Set 5 | wuwei
# Processing Record 22 of Set 5 | the valley
# Processing Record 23 of Set 5 | codajas
# Processing Record 24 of Set 5 | igarka
# Processing Record 25 of Set 5 | nueva germania
# Processing Record 26 of Set 5 | villavieja
# Processing Record 27 of Set 5 | killybegs
# Processing Record 28 of Set 5 | chara
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | bend
# Processing Record 31 of Set 5 | tsiroanomandidy
# Processing Record 32 of Set 5 | aykino
# Processing Record 33 of Set 5 | morgan city
# Processing Record 34 of Set 5 | sarahan
# Processing Record 35 of Set 5 | paita
# Processing Record 36 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | quatre cocos
# Processing Record 40 of Set 5 | verkhnyaya toyma
# Processing Record 41 of Set 5 | hualmay
# Processing Record 42 of Set 5 | oktyabrskiy
# Processing Record 43 of Set 5 | el limon
# Processing Record 44 of Set 5 | quzhou
# Processing Record 45 of Set 5 | san carlos de bariloche
# Processing Record 46 of Set 5 | okha
# Processing Record 47 of Set 5 | asyut
# Processing Record 48 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | beaverlodge
# Processing Record 2 of Set 6 | roald
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | luanda
# Processing Record 5 of Set 6 | pochutla
# Processing Record 6 of Set 6 | la rioja
# Processing Record 7 of Set 6 | diego de almagro
# Processing Record 8 of Set 6 | opuwo
# Processing Record 9 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 6 | kloulklubed
# Processing Record 11 of Set 6 | baruun-urt
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | boffa
# Processing Record 14 of Set 6 | markova
# Processing Record 15 of Set 6 | plettenberg bay
# Processing Record 16 of Set 6 | eston
# Processing Record 17 of Set 6 | bowen
# Processing Record 18 of Set 6 | suntar
# Processing Record 19 of Set 6 | ola
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | nome
# Processing Record 22 of Set 6 | yerbogachen
# Processing Record 23 of Set 6 | tasiilaq
# Processing Record 24 of Set 6 | kenai
# Processing Record 25 of Set 6 | tacuarembo
# Processing Record 26 of Set 6 | bealanana
# Processing Record 27 of Set 6 | porto novo
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | areka
# Processing Record 30 of Set 6 | celestun
# Processing Record 31 of Set 6 | alice springs
# Processing Record 32 of Set 6 | yabrud
# Processing Record 33 of Set 6 | tacna
# Processing Record 34 of Set 6 | mumford
# Processing Record 35 of Set 6 | kulhudhuffushi
# Processing Record 36 of Set 6 | sabang
# Processing Record 37 of Set 6 | maniitsoq
# Processing Record 38 of Set 6 | assiniboia
# Processing Record 39 of Set 6 | lomza
# Processing Record 40 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 6 | olinda
# Processing Record 42 of Set 6 | atherton
# Processing Record 43 of Set 6 | poum
# Processing Record 44 of Set 6 | rio claro
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | beringovskiy
# Processing Record 47 of Set 6 | bombay
# Processing Record 48 of Set 6 | galle
# Processing Record 49 of Set 6 | pontal do parana
# Processing Record 50 of Set 6 | te anau
# Processing Record 1 of Set 7 | sai buri
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | nauta
# Processing Record 4 of Set 7 | igrim
# Processing Record 5 of Set 7 | uruzgan
# Processing Record 6 of Set 7 | alpena
# Processing Record 7 of Set 7 | faya
# Processing Record 8 of Set 7 | lakes entrance
# Processing Record 9 of Set 7 | ati
# Processing Record 10 of Set 7 | parang
# Processing Record 11 of Set 7 | muisne
# Processing Record 12 of Set 7 | vila do maio
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | mazatlan
# Processing Record 15 of Set 7 | ketchikan
# Processing Record 16 of Set 7 | phek
# Processing Record 17 of Set 7 | prata
# Processing Record 18 of Set 7 | woodlyn
# Processing Record 19 of Set 7 | vao
# Processing Record 20 of Set 7 | kutum
# Processing Record 21 of Set 7 | nelson bay
# Processing Record 22 of Set 7 | hervey bay
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | saint-pierre
# Processing Record 25 of Set 7 | buritis
# Processing Record 26 of Set 7 | mamaku
# Processing Record 27 of Set 7 | saint-philippe
# Processing Record 28 of Set 7 | mantua
# Processing Record 29 of Set 7 | nantucket
# Processing Record 30 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 7 | tromso
# Processing Record 32 of Set 7 | marseille
# Processing Record 33 of Set 7 | moose jaw
# Processing Record 34 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 7 | baiyin
# Processing Record 36 of Set 7 | zhangye
# Processing Record 37 of Set 7 | phalaborwa
# Processing Record 38 of Set 7 | tambura
# Processing Record 39 of Set 7 | bendigo
# Processing Record 40 of Set 7 | ucluelet
# Processing Record 41 of Set 7 | yuzhou
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | eyrarbakki
# Processing Record 44 of Set 7 | ballstad
# City not found. Skipping...
# Processing Record 45 of Set 7 | erdenet
# Processing Record 46 of Set 7 | kidal
# Processing Record 47 of Set 7 | seoul
# Processing Record 48 of Set 7 | kungurtug
# Processing Record 49 of Set 7 | dahuk
# Processing Record 50 of Set 7 | saskylakh
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | bartica
# Processing Record 3 of Set 8 | dinguiraye
# Processing Record 4 of Set 8 | itoman
# Processing Record 5 of Set 8 | cheremukhovo
# Processing Record 6 of Set 8 | bogotol
# Processing Record 7 of Set 8 | severo-kurilsk
# Processing Record 8 of Set 8 | kozhva
# Processing Record 9 of Set 8 | buzmeyin
# Processing Record 10 of Set 8 | jardim
# Processing Record 11 of Set 8 | tobias barreto
# Processing Record 12 of Set 8 | labytnangi
# Processing Record 13 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 8 | summerville
# Processing Record 15 of Set 8 | requena
# Processing Record 16 of Set 8 | lubbock
# Processing Record 17 of Set 8 | sao gabriel da cachoeira
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | kasongo-lunda
# Processing Record 20 of Set 8 | saint-joseph
# Processing Record 21 of Set 8 | rawah
# Processing Record 22 of Set 8 | lorengau
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | nakusp
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | kysyl-syr
# Processing Record 27 of Set 8 | camocim
# Processing Record 28 of Set 8 | sikasso
# Processing Record 29 of Set 8 | leningradskiy
# Processing Record 30 of Set 8 | jumla
# Processing Record 31 of Set 8 | hanzhong
# Processing Record 32 of Set 8 | awbari
# Processing Record 33 of Set 8 | martil
# Processing Record 34 of Set 8 | grafton
# Processing Record 35 of Set 8 | leshukonskoye
# Processing Record 36 of Set 8 | saint george
# Processing Record 37 of Set 8 | yasnyy
# Processing Record 38 of Set 8 | palana
# Processing Record 39 of Set 8 | college
# Processing Record 40 of Set 8 | san patricio
# Processing Record 41 of Set 8 | jamkhed
# Processing Record 42 of Set 8 | tutoia
# Processing Record 43 of Set 8 | mosquera
# Processing Record 44 of Set 8 | bayir
# Processing Record 45 of Set 8 | soyo
# Processing Record 46 of Set 8 | lieksa
# Processing Record 47 of Set 8 | manoel urbano
# Processing Record 48 of Set 8 | kashi
# Processing Record 49 of Set 8 | general pico
# Processing Record 50 of Set 8 | nioro
# Processing Record 1 of Set 9 | bambous virieux
# Processing Record 2 of Set 9 | evreux
# Processing Record 3 of Set 9 | ilulissat
# Processing Record 4 of Set 9 | villa union
# Processing Record 5 of Set 9 | esil
# Processing Record 6 of Set 9 | baherden
# Processing Record 7 of Set 9 | nanortalik
# Processing Record 8 of Set 9 | hofn
# Processing Record 9 of Set 9 | nadym
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | banda aceh
# Processing Record 12 of Set 9 | manubul
# Processing Record 13 of Set 9 | port elizabeth
# Processing Record 14 of Set 9 | methven
# Processing Record 15 of Set 9 | ahualulco
# Processing Record 16 of Set 9 | macultepec
# Processing Record 17 of Set 9 | westport
# Processing Record 18 of Set 9 | pisco
# Processing Record 19 of Set 9 | okhotsk
# Processing Record 20 of Set 9 | hohhot
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | shenkursk
# Processing Record 23 of Set 9 | maroantsetra
# Processing Record 24 of Set 9 | broken hill
# Processing Record 25 of Set 9 | emirdag
# Processing Record 26 of Set 9 | tongzi
# Processing Record 27 of Set 9 | tura
# Processing Record 28 of Set 9 | bonavista
# Processing Record 29 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 9 | tadine
# Processing Record 33 of Set 9 | pudozh
# Processing Record 34 of Set 9 | kismayo
# Processing Record 35 of Set 9 | kalas
# Processing Record 36 of Set 9 | hasaki
# Processing Record 37 of Set 9 | puri
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | nhulunbuy
# Processing Record 40 of Set 9 | semirom
# Processing Record 41 of Set 9 | saldanha
# Processing Record 42 of Set 9 | tiarei
# Processing Record 43 of Set 9 | galesong
# Processing Record 44 of Set 9 | roma
# Processing Record 45 of Set 9 | yuksekova
# Processing Record 46 of Set 9 | walvis bay
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | manono
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | gualeguay
# Processing Record 1 of Set 10 | chicama
# Processing Record 2 of Set 10 | makat
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | baft
# Processing Record 5 of Set 10 | oyama
# Processing Record 6 of Set 10 | nioaque
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | manzhouli
# Processing Record 9 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 10 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 11 of Set 10 | svetlaya
# Processing Record 12 of Set 10 | imbituba
# Processing Record 13 of Set 10 | narsaq
# Processing Record 14 of Set 10 | bandiagara
# Processing Record 15 of Set 10 | ojinaga
# Processing Record 16 of Set 10 | zhuhai
# Processing Record 17 of Set 10 | santa cruz de tenerife
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 10 | fairbanks
# Processing Record 20 of Set 10 | olafsvik
# Processing Record 21 of Set 10 | alto araguaia
# Processing Record 22 of Set 10 | aswan
# Processing Record 23 of Set 10 | russkaya polyana
# Processing Record 24 of Set 10 | muriwai beach
# Processing Record 25 of Set 10 | kavant
# City not found. Skipping...
# Processing Record 26 of Set 10 | wagar
# Processing Record 27 of Set 10 | amapa
# Processing Record 28 of Set 10 | fujin
# Processing Record 29 of Set 10 | northam
# Processing Record 30 of Set 10 | emsdetten
# Processing Record 31 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 10 | demirci
# Processing Record 33 of Set 10 | mangrol
# Processing Record 34 of Set 10 | muros
# Processing Record 35 of Set 10 | kawalu
# Processing Record 36 of Set 10 | linguere
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | weimar
# Processing Record 39 of Set 10 | ponta do sol
# Processing Record 40 of Set 10 | alofi
# Processing Record 41 of Set 10 | colac
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | smithers
# Processing Record 44 of Set 10 | tevriz
# Processing Record 45 of Set 10 | marsh harbour
# Processing Record 46 of Set 10 | elat
# Processing Record 47 of Set 10 | klyuchi
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | leo
# Processing Record 50 of Set 10 | olga
# Processing Record 1 of Set 11 | dingle
# Processing Record 2 of Set 11 | toora-khem
# Processing Record 3 of Set 11 | lebu
# Processing Record 4 of Set 11 | bose
# Processing Record 5 of Set 11 | hun
# Processing Record 6 of Set 11 | kaura namoda
# Processing Record 7 of Set 11 | naifaru
# Processing Record 8 of Set 11 | enid
# Processing Record 9 of Set 11 | saravan
# Processing Record 10 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 11 | jaggayyapeta
# Processing Record 12 of Set 11 | tual
# Processing Record 13 of Set 11 | sibolga
# Processing Record 14 of Set 11 | broadview heights
# Processing Record 15 of Set 11 | lazaro cardenas
# Processing Record 16 of Set 11 | oranjemund
# Processing Record 17 of Set 11 | norrtalje
# Processing Record 18 of Set 11 | kadyy
# Processing Record 19 of Set 11 | medveda
# Processing Record 20 of Set 11 | gbarnga
# Processing Record 21 of Set 11 | ukiah
# Processing Record 22 of Set 11 | porto seguro
# Processing Record 23 of Set 11 | stryn
# Processing Record 24 of Set 11 | danville
# Processing Record 25 of Set 11 | mitsamiouli
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 11 | anito
# Processing Record 29 of Set 11 | ancud
# Processing Record 30 of Set 11 | kalmunai
# Processing Record 31 of Set 11 | upata
# Processing Record 32 of Set 11 | katobu
# Processing Record 33 of Set 11 | balkhash
# Processing Record 34 of Set 11 | vostok
# Processing Record 35 of Set 11 | fort smith
# Processing Record 36 of Set 11 | nachingwea
# Processing Record 37 of Set 11 | limbang
# Processing Record 38 of Set 11 | derzhavinsk
# Processing Record 39 of Set 11 | korla
# Processing Record 40 of Set 11 | havre
# Processing Record 41 of Set 11 | vavoua
# Processing Record 42 of Set 11 | sampit
# Processing Record 43 of Set 11 | semnan
# Processing Record 44 of Set 11 | ornskoldsvik
# Processing Record 45 of Set 11 | chalons-en-champagne
# Processing Record 46 of Set 11 | illertissen
# Processing Record 47 of Set 11 | preili
# Processing Record 48 of Set 11 | vikulovo
# Processing Record 49 of Set 11 | salym
# Processing Record 50 of Set 11 | kati
# Processing Record 1 of Set 12 | komsomolskiy
# Processing Record 2 of Set 12 | bahia blanca
# Processing Record 3 of Set 12 | baglung
# Processing Record 4 of Set 12 | bintulu
# Processing Record 5 of Set 12 | kieta
# Processing Record 6 of Set 12 | san-pedro
# Processing Record 7 of Set 12 | alihe
# Processing Record 8 of Set 12 | borujerd
# Processing Record 9 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 12 | simbahan
# Processing Record 11 of Set 12 | chunoyar
# Processing Record 12 of Set 12 | lagoa
# Processing Record 13 of Set 12 | nabire
# Processing Record 14 of Set 12 | calabozo
# Processing Record 15 of Set 12 | souillac
# Processing Record 16 of Set 12 | bambanglipuro
# Processing Record 17 of Set 12 | fairview
# Processing Record 18 of Set 12 | srednekolymsk
# Processing Record 19 of Set 12 | waingapu
# Processing Record 20 of Set 12 | jacksonville
# Processing Record 21 of Set 12 | coihaique
# Processing Record 22 of Set 12 | mastung
# Processing Record 23 of Set 12 | bichura
# Processing Record 24 of Set 12 | ananas
# Processing Record 25 of Set 12 | may pen
# Processing Record 26 of Set 12 | posevnaya
# Processing Record 27 of Set 12 | hazelwood
# Processing Record 28 of Set 12 | rochester
# Processing Record 29 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 12 | willowmore
# Processing Record 31 of Set 12 | bogalusa
# Processing Record 32 of Set 12 | lingyuan
# Processing Record 33 of Set 12 | den helder
# Processing Record 34 of Set 12 | kailua
# Processing Record 35 of Set 12 | belyy yar
# Processing Record 36 of Set 12 | udachnyy
# Processing Record 37 of Set 12 | nuuk
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 12 | beaufort
# Processing Record 42 of Set 12 | arai
# Processing Record 43 of Set 12 | sambava
# Processing Record 44 of Set 12 | awjilah
# Processing Record 45 of Set 12 | eresos
# Processing Record 46 of Set 12 | juybar
# Processing Record 47 of Set 12 | kholtoson
# Processing Record 48 of Set 12 | speightstown
# Processing Record 49 of Set 12 | guarapari
# Processing Record 50 of Set 12 | lata
# Processing Record 1 of Set 13 | zhigansk
# Processing Record 2 of Set 13 | ginir
# Processing Record 3 of Set 13 | pacific grove
# Processing Record 4 of Set 13 | ansermanuevo
# Processing Record 5 of Set 13 | jagtial
# Processing Record 6 of Set 13 | orsha
# Processing Record 7 of Set 13 | batouri
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | teya
# Processing Record 10 of Set 13 | birao
# Processing Record 11 of Set 13 | provideniya
# Processing Record 12 of Set 13 | kinablangan
# Processing Record 13 of Set 13 | abeche
# Processing Record 14 of Set 13 | tandil
# Processing Record 15 of Set 13 | thinadhoo
# Processing Record 16 of Set 13 | yevlax
# Processing Record 17 of Set 13 | filadelfia
# Processing Record 18 of Set 13 | pandan
# Processing Record 19 of Set 13 | cap malheureux
# Processing Record 20 of Set 13 | santa catarina de tepehuanes
# Processing Record 21 of Set 13 | grootfontein
# Processing Record 22 of Set 13 | conde
# Processing Record 23 of Set 13 | leh
# Processing Record 24 of Set 13 | oistins
# Processing Record 25 of Set 13 | havoysund
# Processing Record 26 of Set 13 | leshan
# Processing Record 27 of Set 13 | pundaguitan
# Processing Record 28 of Set 13 | amboasary
# Processing Record 29 of Set 13 | barcelona
# Processing Record 30 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 13 | boca do acre
# Processing Record 32 of Set 13 | great malvern
# Processing Record 33 of Set 13 | usinsk
# Processing Record 34 of Set 13 | calbuco
# Processing Record 35 of Set 13 | shimanovsk
# Processing Record 36 of Set 13 | pasighat
# Processing Record 37 of Set 13 | dobson
# Processing Record 38 of Set 13 | kalbay
# Processing Record 39 of Set 13 | hong gai
# Processing Record 40 of Set 13 | byron bay
# Processing Record 41 of Set 13 | wanning
# Processing Record 42 of Set 13 | jimo
# Processing Record 43 of Set 13 | la plata
# Processing Record 44 of Set 13 | kunigal
# Processing Record 45 of Set 13 | pangnirtung
# Processing Record 46 of Set 13 | hoganas
# Processing Record 47 of Set 13 | shenjiamen
# Processing Record 48 of Set 13 | paragominas
# Processing Record 49 of Set 13 | troitskoye
# Processing Record 50 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 14 | sepolno krajenskie
# Processing Record 2 of Set 14 | nizhniy novgorod
# Processing Record 3 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 14 | miri
# Processing Record 5 of Set 14 | kyzyl-suu
# Processing Record 6 of Set 14 | odessa
# Processing Record 7 of Set 14 | puerto madryn
# Processing Record 8 of Set 14 | iwanai
# Processing Record 9 of Set 14 | maungaturoto
# Processing Record 10 of Set 14 | manaure
# Processing Record 11 of Set 14 | nakhon sawan
# Processing Record 12 of Set 14 | honiara
# Processing Record 13 of Set 14 | north bend
# Processing Record 14 of Set 14 | simao
# Processing Record 15 of Set 14 | tabas
# Processing Record 16 of Set 14 | fort nelson
# Processing Record 17 of Set 14 | rodrigues alves
# Processing Record 18 of Set 14 | novyy urengoy
# Processing Record 19 of Set 14 | ingham
# Processing Record 20 of Set 14 | djambala
# Processing Record 21 of Set 14 | owerri
# Processing Record 22 of Set 14 | villa carlos paz
# Processing Record 23 of Set 14 | lufilufi
# Processing Record 24 of Set 14 | novotalitsy
# City not found. Skipping...
# Processing Record 25 of Set 14 | hoshcha
# Processing Record 26 of Set 14 | huarmey
# Processing Record 27 of Set 14 | burnie
# Processing Record 28 of Set 14 | pingliang
# Processing Record 29 of Set 14 | natal
# Processing Record 30 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 14 | buala
# Processing Record 32 of Set 14 | san pedro
# Processing Record 33 of Set 14 | saverne
# Processing Record 34 of Set 14 | nurota
# Processing Record 35 of Set 14 | mangrul pir
# Processing Record 36 of Set 14 | kishtwar
# Processing Record 37 of Set 14 | troitsko-pechorsk
# Processing Record 38 of Set 14 | sangar
# Processing Record 39 of Set 14 | manavalakurichi
# Processing Record 40 of Set 14 | kondagaon
# Processing Record 41 of Set 14 | dong hoi
# Processing Record 42 of Set 14 | borova
# Processing Record 43 of Set 14 | mayna
# Processing Record 44 of Set 14 | cururupu
# Processing Record 45 of Set 14 | paamiut
# Processing Record 46 of Set 14 | mirnyy
# Processing Record 47 of Set 14 | skjervoy
# Processing Record 48 of Set 14 | gigmoto
# Processing Record 49 of Set 14 | kropotkin
# Processing Record 50 of Set 14 | port shepstone
# Processing Record 1 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 2 of Set 15 | namtsy
# Processing Record 3 of Set 15 | lukovetskiy
# Processing Record 4 of Set 15 | tenenkou
# Processing Record 5 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 15 | bubaque
# Processing Record 7 of Set 15 | lasem
# Processing Record 8 of Set 15 | xuzhou
# Processing Record 9 of Set 15 | asau
# Processing Record 10 of Set 15 | moron
# Processing Record 11 of Set 15 | dunkirk
# Processing Record 12 of Set 15 | hami
# Processing Record 13 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 15 | anavra
# Processing Record 15 of Set 15 | ossora
# Processing Record 16 of Set 15 | severo-yeniseyskiy
# Processing Record 17 of Set 15 | camacha
# Processing Record 18 of Set 15 | grindavik
# Processing Record 19 of Set 15 | eching
# Processing Record 20 of Set 15 | privolzhye
# Processing Record 21 of Set 15 | beloha
# Processing Record 22 of Set 15 | quetzaltepec
# City not found. Skipping...
# Processing Record 23 of Set 15 | penzance
# Processing Record 24 of Set 15 | christchurch
# Processing Record 25 of Set 15 | santa maria
# Processing Record 26 of Set 15 | kirakira
# Processing Record 27 of Set 15 | kataysk
# Processing Record 28 of Set 15 | bay city
# Processing Record 29 of Set 15 | moree
# Processing Record 30 of Set 15 | acapulco
# Processing Record 31 of Set 15 | santa isabel do rio negro
# Processing Record 32 of Set 15 | thai binh
# Processing Record 33 of Set 15 | vila velha
# Processing Record 34 of Set 15 | gotsu
# Processing Record 35 of Set 15 | chapais
# Processing Record 36 of Set 15 | mercedes
# Processing Record 37 of Set 15 | oga
# Processing Record 38 of Set 15 | matay
# Processing Record 39 of Set 15 | baykit
# Processing Record 40 of Set 15 | glasgow
# Processing Record 41 of Set 15 | nouakchott
# Processing Record 42 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 15 | tilichiki
# Processing Record 44 of Set 15 | ambilobe
# Processing Record 45 of Set 15 | ejura
# Processing Record 46 of Set 15 | pochinki
# Processing Record 47 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 15 | chichli
# Processing Record 49 of Set 15 | texarkana
# Processing Record 50 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 16 | madang
# Processing Record 2 of Set 16 | sioux lookout
# Processing Record 3 of Set 16 | kindu
# Processing Record 4 of Set 16 | sussex
# Processing Record 5 of Set 16 | boende
# Processing Record 6 of Set 16 | khammam
# Processing Record 7 of Set 16 | jaru
# Processing Record 8 of Set 16 | burica
# City not found. Skipping...
# Processing Record 9 of Set 16 | abapo
# Processing Record 10 of Set 16 | acarau

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
#Column Reorder
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_final_df = city_data_df[new_column_order]

# %%
city_data_final_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
